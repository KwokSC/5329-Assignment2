# %% [markdown]
# # **Instruction**
#
# We built a classifier model for the particular multi-label image classification task, trained and validated on the 30000 training data set. When running the code, please refer to the table of contents and comments in the .ipynb file and run the code from top to bottom. One of the experiment result has been shown in the Training model section.

# %% [markdown]
# ### **1.1 Package import**
#
# In this section, package needed would be imported and at the same time, we will apply the access to the Google Drive in order to download data insection 2.1(Data Loading).

# %%
import numpy as np
import re
import pandas as pd
import os

# torch package
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms, models

import io
from io import StringIO
from itertools import chain
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
import time
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# NLP technology package
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
nltk.download('averaged_perceptron_tagger')
from nltk.tag.perceptron import PerceptronTagger
import gensim.downloader as api

# Apply to the google drive
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials


auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# ### **1.2 Hyperparameters setting**
#
# This unit contains most of the parameters that will be used in our model
# Our project team mainly conducts comparison experiments by changing the value of hyperparameters in this cell

# %%
# show thw runnnig time type
in_cuda = torch.cuda.is_available()
device = torch.device('cuda' if in_cuda else 'cpu')
if using_cuda:
    print(torch.cuda.get_device_properties(device))

# some hyperparameters
label_nums = 20                                   # length of label
dataPath = './data/'                              # load the data
LEAST_FREQUENCY = 1                               # time of word show time
SEQUENCE_LENGTH = 8                               # the length of a sentence
VALIDATION_RATIO = 0.2                            # split the dataset
BATCH_SIZE = 32                                   # batch size
LEARNING_RATE = 8e-5                              # lr 
DROPOUT = 0.3                                     # Dropout
THRESHOLD = 0.3                                   # probability threshlod of output
NUM_EPOCHS = 7                                    # epoch nums

kwargs = {'num_workers': 1, 'pin_memory': True} if using_cuda else {}
# Out:
# We are using cuda.
# _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %% [markdown]
# ### **1.3 Supporting Fuctions**
#
# We have created many support functions for subsequent experiments, such as nlp preprocessing, data loading, etc. These support functions will be explained in this section.

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
nltk.download('averaged_perceptron_tagger')
from nltk.tag.perceptron import PerceptronTagger
import gensim.downloader as api

# the function is used. to read the file 
def csv_read(file_load):
    with open(file_load) as CsvFile:
        lines = [re.sub(r'([^,])"(\s*[^\n])', r'\1/"\2', line) for line in CsvFile]
    return pd.read_csv(StringIO(''.join(lines)), escapechar="/")

# preprocess caption
def nlp_process(PathTa, PathTe,label_nums,emb_model):
    # read the file to get information
    ListTa = csv_read(PathTa)
    ListTe = csv_read(PathTe)
    # get different aspect from list  train and test
    traImageId = ListTa['ImageID'].tolist()
    traLable = ListTa['Labels'].tolist()
    traCaption = ListTa['Caption'].tolist()
    testImageId = ListTe['ImageID'].tolist()
    testCaption = ListTe['Caption'].tolist()

    # just change the labels into one-hot
    TransKit = MultiLabelBinarizer().fit([np.arange(label_nums)])
    traLabelsL = [[int(label) for label in labels.split()] for labels in traLable]
    traLable = TransKit.transform(traLabelsL)

    # NLP. preprocess
    lemmatizer = WordNetLemmatizer()
    stop_words = stopwords.words('english')
    word_error = {'windsurfs','kiteboards','tball','skiboard','bluewhite',  'krispee', 'deckered',
                'firsbee', 'frizbee',  'snowcovered',  'rared','surfboarding',  'umbrells',
                'midswing',  'firehydrant',  'frisbe','skii', 'skiies', 'surfboarder', 
                'baeball','parasailers','basball','fourwheeler','checkerd','blackandwhite'}
    for idx, sentence in enumerate(traCaption):
        # remove punctuation
        sentence = re.sub(r'[^\w\s]', '', sentence)
        # lowcase 
        sentence = sentence.lower()
        # tokenize the sentence. split into one words list
        sentence = word_tokenize(sentence)
        # remove stop words from list
        sentence = [word for word in sentence if not word in stop_words]
        # do lemmatization
        # sentence = [lemmatizer.lemmatize(word) for word in sentence]
        # pos tagger
        pos_tagger = PerceptronTagger()
        tag_set = set(['NN', 'NNS', 'NNP', 'NNPS', 'VBG'])
        sentence =   [word for word in sentence if pos_tagger.tag(word.split())[0][1] in tag_set or word == 'puppy']
        # remove spell error
        sentence = [word for word in sentence if not word in word_error]
        traCaption[idx] = sentence


    # for test
    for idx, sentence in enumerate(testCaption):

        # remove punctuation
        sentence = re.sub(r'[^\w\s]', '', sentence)
        # lowcase 
        sentence = sentence.lower()
        # tokenize the sentence. split into one words list
        sentence = word_tokenize(sentence)
        # remove stop words from list
        sentence = [word for word in sentence if not word in stop_words]
        # do lemmatization
        # sentence = [lemmatizer.lemmatize(word) for word in sentence]
        # pos tagger
        pos_tagger = PerceptronTagger()
        tag_set = set(['NN', 'NNS', 'NNP', 'NNPS', 'VBG'])
        sentence =   [word for word in sentence if pos_tagger.tag(word.split())[0][1] in tag_set or word == 'puppy']
        # remove spell error
        sentence = [word for word in sentence if not word in word_error]
        testCaption[idx] = sentence

    # count words apperance times.
    freqWord = {}
    for abs in traCaption:
        for word in abs:
            try:
                freqWord[word] += 1
            except KeyError:
                freqWord[word] = 1
    for ads in testCaption:
        for word in ads:
            try:
                freqWord[word] += 1
            except KeyError:
                freqWord[word] = 1
    freq_list = freqWord


    # delet the rarely apperanced words
    traHighWords = []
    for wordOne in traCaption:
        temp = []
        for word in wordOne:
            # 1 represent the leaset time of a word is 2
            if freq_list[word] > 1:  
                temp.append(word)
        if len(temp) == 0:
            traHighWords.append(wordOne)
        else:
            traHighWords.append(temp)
    trainCaption = traHighWords

    testHigh = []
    for wordTwo in testCaption:
        temp = []
        for word in wordTwo:
            # 1 represent the leaset time of a word is 2
            if freq_list[word] > 1:
                temp.append(word)
        if len(temp) == 0:
            testHigh.append(wordTwo)
        else:
            testHigh.append(temp)
    testCaption = testHigh

    # do padding process
    output_train = []
    for wordlistaa in trainCaption:
        while len(wordlistaa) < 8 :
            wordlistaa = wordlistaa * 2
        output_train.append(wordlistaa[: 8])
    trainCaption = output_train

    output_test = []
    for wordlistbb in testCaption:
        while len(wordlistbb) < 8:
            wordlistbb = wordlistbb * 2
        output_test.append(wordlistbb[: 8])
    testCaption = output_test


    # use word_embeding to represent real word by pretrained model
    emb_dim = emb_model.vector_size
    output_train = []
    for dimWordaa in trainCaption:
        out_temp = []
        for word in dimWordaa:
            try:
                out_temp.append(emb_model.wv[word])
            except:
                out_temp.append(np.array([0.0] * emb_dim, np.float32))    
        output_train.append(out_temp)
    trainCaption = np.array(output_train, np.float32)

    # for test 
    output_test = []
    for dimWordbb in testCaption:
        out_temp = []
        for word in dimWordbb:
            try:
                out_temp.append(emb_model.wv[word])
            except:
                out_temp.append(np.array([0.0] * emb_dim, np.float32))    
        output_test.append(out_temp)
    testCaption = np.array(output_test, np.float32)

    return traImageId,trainCaption,traLable,testImageId,testCaption



# define how to preprocess image information
# https://pytorch.org/docs/stable/torchvision/transforms.html#transforms-on-torch-tensor
image_transforms = {
    'train': transforms.Compose([
        #improve picture quality
        transforms.ColorJitter(brightness=0.15, contrast=0.1, hue=0.2),                         
        transforms.Resize(256),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.463, 0.449, 0.421], [0.241, 0.234, 0.238])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.463, 0.449, 0.421], [0.241, 0.234, 0.238])
    ]),
}

# define how to load image from directory
def load_image(dataId):
    return Image.open(os.path.join(dataPath, dataId))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ### **2.1 Data loading**
#
# Load the trainingh and test data sets and unzip them

# %%
# download zip file from my Google Drive and unzip it
id = '1dtjKoWgZO_gYm7Kt94jVnZgbjlrG8DVi'
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('dataset')

# !unzip dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/550.jpg
#   inflating: data/5500.jpg
#   inflating: data/5501.jpg
#   inflating: data/5502.jpg
#   inflating: data/5503.jpg
#   inflating: data/5504.jpg
#   inflating: data/5505.jpg
#   inflating: data/5506.jpg
#   inflating: data/5507.jpg
#   inflating: data/5508.jpg
#   inflating: data/5509.jpg
#   inflating: data/551.jpg
#   inflating: data/5510.jpg
#   inflating: data/5511.jpg
#   inflating: data/5512.jpg
#   inflating: data/5513.jpg
#   inflating: data/5514.jpg
#   inflating: data/5515.jpg
#   inflating: data/5516.jpg
#   inflating: data/5517.jpg
#   inflating: data/5518.jpg
#   inflating: data/5519.jpg
#   inflating: data/552.jpg
#   inflating: data/5520.jpg
#   inflating: data/5521.jpg
#   inflating: data/5522.jpg
#   inflating: data/5523.jpg
#   inflating: data/5524.jpg
#   inflating: data/5525.jpg
#   inflating: data/5526.jpg
#   inflating: data/5527.jpg
#   inflating: data/5528.jpg
#   inflating: data/5529.jpg
#   inflating: data/553.jpg
#   inflating: data/5530.jpg
#   inflating: data/5531.jpg
#   inflating: data/5532.jpg
#   inflating: data/5533.jpg
#   inflating: data/5534.jpg
#   inflating: data/5535.jpg
#   inflating: data/5536.jpg
#   inflating: data/5537.jpg
#   inflating: data/5538.jpg
#   inflating: data/5539.jpg
#   inflating: data/554.jpg
#   inflating: data/5540.jpg
#   inflating: data/5541.jpg
#   inflating: data/5542.jpg
#   inflating: data/5543.jpg
#   inflating: data/5544.jpg
#   inflating: data/5545.jpg
#   inflating: data/5546.jpg
#   inflating: data/5547.jpg
#   inflating: data/5548.jpg
#   inflating: data/5549.jpg
#   inflating: data/555.jpg
#   inflating: data/5550.jpg
#   inflating: data/5551.jpg
#   inflating: data/5552.jpg
#   inflating: data/5553.jpg
#   inflating: data/5554.jpg
#   inflating: data/5555.jpg
#   inflating: data/5556.jpg
#   inflating: data/5557.jpg
#   inflating: data/5558.jpg
#   inflating: data/5559.jpg
#   inflating: data/556.jpg
#   inflating: data/5560.jpg
#   inflating: data/5561.jpg
#   inflating: data/5562.jpg
#   inflating: data/5563.jpg
#   inflating: data/5564.jpg
#   inflating: data/5565.jpg
#   inflating: data/5566.jpg
#   inflating: data/5567.jpg
#   inflating: data/5568.jpg
#   inflating: data/5569.jpg
#   inflating: data/557.jpg
#   inflating: data/5570.jpg
#   inflating: data/5571.jpg
#   inflating: data/5572.jpg
#   inflating: data/5573.jpg
#   inflating: data/5574.jpg
#   inflating: data/5575.jpg
#   inflating: data/5576.jpg
#   inflating: data/5577.jpg
#   inflating: data/5578.jpg
#   inflating: data/5579.jpg
#   inflating: data/558.jpg
#   inflating: data/5580.jpg
#   inflating: data/5581.jpg
#   inflating: data/5582.jpg
#   inflating: data/5583.jpg
#   inflating: data/5584.jpg
#   inflating: data/5585.jpg
#   inflating: data/5586.jpg
#   inflating: data/5587.jpg
#   inflating: data/5588.jpg
#   inflating: data/5589.jpg
#   inflating: data/559.jpg
#   inflating: data/5590.jpg
#   inflating: data/5591.jpg
#   inflating: data/5592.jpg
#   inflating: data/5593.jpg
#   inflating: data/5594.jpg
#   inflating: data/5595.jpg
#   inflating: data/5596.jpg
#   inflating: data/5597.jpg
#   inflating: data/5598.jpg
#   inflating: data/5599.jpg
#   inflating: data/56.jpg
#   inflating: data/560.jpg
#   inflating: data/5600.jpg
#   inflating: data/5601.jpg
#   inflating: data/5602.jpg
#   inflating: data/5603.jpg
#   inflating: data/5604.jpg
#   inflating: data/5605.jpg
#   inflating: data/5606.jpg
#   inflating: data/5607.jpg
#   inflating: data/5608.jpg
#   inflating: data/5609.jpg
#   inflating: data/561.jpg
#   inflating: data/5610.jpg
#   inflating: data/5611.jpg
#   inflating: data/5612.jpg
#   inflating: data/5613.jpg
#   inflating: data/5614.jpg
#   inflating: data/5615.jpg
#   inflating: data/5616.jpg
#   inflating: data/5617.jpg
#   inflating: data/5618.jpg
#   inflating: data/5619.jpg
#   inflating: data/562.jpg
#   inflating: data/5620.jpg
#   inflating: data/5621.jpg
#   inflating: data/5622.jpg
#   inflating: data/5623.jpg
#   inflating: data/5624.jpg
#   inflating: data/5625.jpg
#   inflating: data/5626.jpg
#   inflating: data/5627.jpg
#   inflating: data/5628.jpg
#   inflating: data/5629.jpg
#   inflating: data/563.jpg
#   inflating: data/5630.jpg
#   inflating: data/5631.jpg
#   inflating: data/5632.jpg
#   inflating: data/5633.jpg
#   inflating: data/5634.jpg
#   inflating: data/5635.jpg
#   inflating: data/5636.jpg
#   inflating: data/5637.jpg
#   inflating: data/5638.jpg
#   inflating: data/5639.jpg
#   inflating: data/564.jpg
#   inflating: data/5640.jpg
#   inflating: data/5641.jpg
#   inflating: data/5642.jpg
#   inflating: data/5643.jpg
#   inflating: data/5644.jpg
#   inflating: data/5645.jpg
#   inflating: data/5646.jpg
#   inflating: data/5647.jpg
#   inflating: data/5648.jpg
#   inflating: data/5649.jpg
#   inflating: data/565.jpg
#   inflating: data/5650.jpg
#   inflating: data/5651.jpg
#   inflating: data/5652.jpg
#   inflating: data/5653.jpg
#   inflating: data/5654.jpg
#   inflating: data/5655.jpg
#   inflating: data/5656.jpg
#   inflating: data/5657.jpg
#   inflating: data/5658.jpg
#   inflating: data/5659.jpg
#   inflating: data/566.jpg
#   inflating: data/5660.jpg
#   inflating: data/5661.jpg
#   inflating: data/5662.jpg
#   inflating: data/5663.jpg
#   inflating: data/5664.jpg
#   inflating: data/5665.jpg
#   inflating: data/5666.jpg
#   inflating: data/5667.jpg
#   inflating: data/5668.jpg
#   inflating: data/5669.jpg
#   inflating: data/567.jpg
#   inflating: data/5670.jpg
#   inflating: data/5671.jpg
#   inflating: data/5672.jpg
#   inflating: data/5673.jpg
#   inflating: data/5674.jpg
#   inflating: data/5675.jpg
#   inflating: data/5676.jpg
#   inflating: data/5677.jpg
#   inflating: data/5678.jpg
#   inflating: data/5679.jpg
#   inflating: data/568.jpg
#   inflating: data/5680.jpg
#   inflating: data/5681.jpg
#   inflating: data/5682.jpg
#   inflating: data/5683.jpg
#   inflating: data/5684.jpg
#   inflating: data/5685.jpg
#   inflating: data/5686.jpg
#   inflating: data/5687.jpg
#   inflating: data/5688.jpg
#   inflating: data/5689.jpg
#   inflating: data/569.jpg
#   inflating: data/5690.jpg
#   inflating: data/5691.jpg
#   inflating: data/5692.jpg
#   inflating: data/5693.jpg
#   inflating: data/5694.jpg
#   inflating: data/5695.jpg
#   inflating: data/5696.jpg
#   inflating: data/5697.jpg
#   inflating: data/5698.jpg
#   inflating: data/5699.jpg
#   inflating: data/57.jpg
#   inflating: data/570.jpg
#   inflating: data/5700.jpg
#   inflating: data/5701.jpg
#   inflating: data/5702.jpg
#   inflating: data/5703.jpg
#   inflating: data/5704.jpg
#   inflating: data/5705.jpg
#   inflating: data/5706.jpg
#   inflating: data/5707.jpg
#   inflating: data/5708.jpg
#   inflating: data/5709.jpg
#   inflating: data/571.jpg
#   inflating: data/5710.jpg
#   inflating: data/5711.jpg
#   inflating: data/5712.jpg
#   inflating: data/5713.jpg
#   inflating: data/5714.jpg
#   inflating: data/5715.jpg
#   inflating: data/5716.jpg
#   inflating: data/5717.jpg
#   inflating: data/5718.jpg
#   inflating: data/5719.jpg
#   inflating: data/572.jpg
#   inflating: data/5720.jpg
#   inflating: data/5721.jpg
#   inflating: data/5722.jpg
#   inflating: data/5723.jpg
#   inflating: data/5724.jpg
#   inflating: data/5725.jpg
#   inflating: data/5726.jpg
#   inflating: data/5727.jpg
#   inflating: data/5728.jpg
#   inflating: data/5729.jpg
#   inflating: data/573.jpg
#   inflating: data/5730.jpg
#   inflating: data/5731.jpg
#   inflating: data/5732.jpg
#   inflating: data/5733.jpg
#   inflating: data/5734.jpg
#   inflating: data/5735.jpg
#   inflating: data/5736.jpg
#   inflating: data/5737.jpg
#   inflating: data/5738.jpg
#   inflating: data/5739.jpg
#   inflating: data/574.jpg
#   inflating: data/5740.jpg
#   inflating: data/5741.jpg
#   inflating: data/5742.jpg
#   inflating: data/5743.jpg
#   inflating: data/5744.jpg
#   inflating: data/5745.jpg
#   inflating: data/5746.jpg
#   inflating: data/5747.jpg
#   inflating: data/5748.jpg
#   inflating: data/5749.jpg
#   inflating: data/575.jpg
#   inflating: data/5750.jpg
#   inflating: data/5751.jpg
#   inflating: data/5752.jpg
#   inflating: data/5753.jpg
#   inflating: data/5754.jpg
#   inflating: data/5755.jpg
#   inflating: data/5756.jpg
#   inflating: data/5757.jpg
#   inflating: data/5758.jpg
#   inflating: data/5759.jpg
#   inflating: data/576.jpg
#   inflating: data/5760.jpg
#   inflating: data/5761.jpg
#   inflating: data/5762.jpg
#   inflating: data/5763.jpg
#   inflating: data/5764.jpg
#   inflating: data/5765.jpg
#   inflating: data/5766.jpg
#   inflating: data/5767.jpg
#   inflating: data/5768.jpg
#   inflating: data/5769.jpg
#   inflating: data/577.jpg
#   inflating: data/5770.jpg
#   inflating: data/5771.jpg
#   inflating: data/5772.jpg
#   inflating: data/5773.jpg
#   inflating: data/5774.jpg
#   inflating: data/5775.jpg
#   inflating: data/5776.jpg
#   inflating: data/5777.jpg
#   inflating: data/5778.jpg
#   inflating: data/5779.jpg
#   inflating: data/578.jpg
#   inflating: data/5780.jpg
#   inflating: data/5781.jpg
#   inflating: data/5782.jpg
#   inflating: data/5783.jpg
#   inflating: data/5784.jpg
#   inflating: data/5785.jpg
#   inflating: data/5786.jpg
#   inflating: data/5787.jpg
#   inflating: data/5788.jpg
#   inflating: data/5789.jpg
#   inflating: data/579.jpg
#   inflating: data/5790.jpg
#   inflating: data/5791.jpg
#   inflating: data/5792.jpg
#   inflating: data/5793.jpg
#   inflating: data/5794.jpg
#   inflating: data/5795.jpg
#   inflating: data/5796.jpg
#   inflating: data/5797.jpg
#   inflating: data/5798.jpg
#   inflating: data/5799.jpg
#   inflating: data/58.jpg
#   inflating: data/580.jpg
#   inflating: data/5800.jpg
#   inflating: data/5801.jpg
#   inflating: data/5802.jpg
#   inflating: data/5803.jpg
#   inflating: data/5804.jpg
#   inflating: data/5805.jpg
#   inflating: data/5806.jpg
#   inflating: data/5807.jpg
#   inflating: data/5808.jpg
#   inflating: data/5809.jpg
#   inflating: data/581.jpg
#   inflating: data/5810.jpg
#   inflating: data/5811.jpg
#   inflating: data/5812.jpg
#   inflating: data/5813.jpg
#   inflating: data/5814.jpg
#   inflating: data/5815.jpg
#   inflating: data/5816.jpg
#   inflating: data/5817.jpg
#   inflating: data/5818.jpg
#   inflating: data/5819.jpg
#   inflating: data/582.jpg
#   inflating: data/5820.jpg
#   inflating: data/5821.jpg
#   inflating: data/5822.jpg
#   inflating: data/5823.jpg
#   inflating: data/5824.jpg
#   inflating: data/5825.jpg
#   inflating: data/5826.jpg
#   inflating: data/5827.jpg
#   inflating: data/5828.jpg
#   inflating: data/5829.jpg
#   inflating: data/583.jpg
#   inflating: data/5830.jpg
#   inflating: data/5831.jpg
#   inflating: data/5832.jpg
#   inflating: data/5833.jpg
#   inflating: data/5834.jpg
#   inflating: data/5835.jpg
#   inflating: data/5836.jpg
#   inflating: data/5837.jpg
#   inflating: data/5838.jpg
#   inflating: data/5839.jpg
#   inflating: data/584.jpg
#   inflating: data/5840.jpg
#   inflating: data/5841.jpg
#   inflating: data/5842.jpg
#   inflating: data/5843.jpg
#   inflating: data/5844.jpg
#   inflating: data/5845.jpg
#   inflating: data/5846.jpg
#   inflating: data/5847.jpg
#   inflating: data/5848.jpg
#   inflating: data/5849.jpg
#   inflating: data/585.jpg
#   inflating: data/5850.jpg
#   inflating: data/5851.jpg
#   inflating: data/5852.jpg
#   inflating: data/5853.jpg
#   inflating: data/5854.jpg
#   inflating: data/5855.jpg
#   inflating: data/5856.jpg
#   inflating: data/5857.jpg
#   inflating: data/5858.jpg
#   inflating: data/5859.jpg
#   inflating: data/586.jpg
#   inflating: data/5860.jpg
#   inflating: data/5861.jpg
#   inflating: data/5862.jpg
#   inflating: data/5863.jpg
#   inflating: data/5864.jpg
#   inflating: data/5865.jpg
#   inflating: data/5866.jpg
#   inflating: data/5867.jpg
#   inflating: data/5868.jpg
#   inflating: data/5869.jpg
#   inflating: data/587.jpg
#   inflating: data/5870.jpg
#   inflating: data/5871.jpg
#   inflating: data/5872.jpg
#   inflating: data/5873.jpg
#   inflating: data/5874.jpg
#   inflating: data/5875.jpg
#   inflating: data/5876.jpg
#   inflating: data/5877.jpg
#   inflating: data/5878.jpg
#   inflating: data/5879.jpg
#   inflating: data/588.jpg
#   inflating: data/5880.jpg
#   inflating: data/5881.jpg
#   inflating: data/5882.jpg
#   inflating: data/5883.jpg
#   inflating: data/5884.jpg
#   inflating: data/5885.jpg
#   inflating: data/5886.jpg
#   inflating: data/5887.jpg
#   inflating: data/5888.jpg
#   inflating: data/5889.jpg
#   inflating: data/589.jpg
#   inflating: data/5890.jpg
#   inflating: data/5891.jpg
#   inflating: data/5892.jpg
#   inflating: data/5893.jpg
#   inflating: data/5894.jpg
#   inflating: data/5895.jpg
#   inflating: data/5896.jpg
#   inflating: data/5897.jpg
#   inflating: data/5898.jpg
#   inflating: data/5899.jpg
#   inflating: data/59.jpg
#   inflating: data/590.jpg
#   inflating: data/5900.jpg
#   inflating: data/5901.jpg
#   inflating: data/5902.jpg
#   inflating: data/5903.jpg
#   inflating: data/5904.jpg
#   inflating: data/5905.jpg
#   inflating: data/5906.jpg
#   inflating: data/5907.jpg
#   inflating: data/5908.jpg
#   inflating: data/5909.jpg
#   inflating: data/591.jpg
#   inflating: data/5910.jpg
#   inflating: data/5911.jpg
#   inflating: data/5912.jpg
#   inflating: data/5913.jpg
#   inflating: data/5914.jpg
#   inflating: data/5915.jpg
#   inflating: data/5916.jpg
#   inflating: data/5917.jpg
#   inflating: data/5918.jpg
#   inflating: data/5919.jpg
#   inflating: data/592.jpg
#   inflating: data/5920.jpg
#   inflating: data/5921.jpg
#   inflating: data/5922.jpg
#   inflating: data/5923.jpg
#   inflating: data/5924.jpg
#   inflating: data/5925.jpg
#   inflating: data/5926.jpg
#   inflating: data/5927.jpg
#   inflating: data/5928.jpg
#   inflating: data/5929.jpg
#   inflating: data/593.jpg
#   inflating: data/5930.jpg
#   inflating: data/5931.jpg
#   inflating: data/5932.jpg
#   inflating: data/5933.jpg
#   inflating: data/5934.jpg
#   inflating: data/5935.jpg
#   inflating: data/5936.jpg
#   inflating: data/5937.jpg
#   inflating: data/5938.jpg
#   inflating: data/5939.jpg
#   inflating: data/594.jpg
#   inflating: data/5940.jpg
#   inflating: data/5941.jpg
#   inflating: data/5942.jpg
#   inflating: data/5943.jpg
#   inflating: data/5944.jpg
#   inflating: data/5945.jpg
#   inflating: data/5946.jpg
#   inflating: data/5947.jpg
#   inflating: data/5948.jpg
#   inflating: data/5949.jpg
#   inflating: data/595.jpg
#   inflating: data/5950.jpg
#   inflating: data/5951.jpg
#   inflating: data/5952.jpg
#   inflating: data/5953.jpg
#   inflating: data/5954.jpg
#   inflating: data/5955.jpg
#   inflating: data/5956.jpg
#   inflating: data/5957.jpg
#   inflating: data/5958.jpg
#   inflating: data/5959.jpg
#   inflating: data/596.jpg
#   inflating: data/5960.jpg
#   inflating: data/5961.jpg
#   inflating: data/5962.jpg
#   inflating: data/5963.jpg
#   inflating: data/5964.jpg
#   inflating: data/5965.jpg
#   inflating: data/5966.jpg
#   inflating: data/5967.jpg
#   inflating: data/5968.jpg
#   inflating: data/5969.jpg
#   inflating: data/597.jpg
#   inflating: data/5970.jpg
#   inflating: data/5971.jpg
#   inflating: data/5972.jpg
#   inflating: data/5973.jpg
#   inflating: data/5974.jpg
#   inflating: data/5975.jpg
#   inflating: data/5976.jpg
#   inflating: data/5977.jpg
#   inflating: data/5978.jpg
#   inflating: data/5979.jpg
#   inflating: data/598.jpg
#   inflating: data/5980.jpg
#   inflating: data/5981.jpg
#   inflating: data/5982.jpg
#   inflating: data/5983.jpg
#   inflating: data/5984.jpg
#   inflating: data/5985.jpg
#   inflating: data/5986.jpg
#   inflating: data/5987.jpg
#   inflating: data/5988.jpg
#   inflating: data/5989.jpg
#   inflating: data/599.jpg
#   inflating: data/5990.jpg
#   inflating: data/5991.jpg
#   inflating: data/5992.jpg
#   inflating: data/5993.jpg
#   inflating: data/5994.jpg
#   inflating: data/5995.jpg
#   inflating: data/5996.jpg
#   inflating: data/5997.jpg
#   inflating: data/5998.jpg
#   inflating: data/5999.jpg
#   inflating: data/6.jpg
#   inflating: data/60.jpg
#   inflating: data/600.jpg
#   inflating: data/6000.jpg
#   inflating: data/6001.jpg
#   inflating: data/6002.jpg
#   inflating: data/6003.jpg
#   inflating: data/6004.jpg
#   inflating: data/6005.jpg
#   inflating: data/6006.jpg
#   inflating: data/6007.jpg
#   inflating: data/6008.jpg
#   inflating: data/6009.jpg
#   inflating: data/601.jpg
#   inflating: data/6010.jpg
#   inflating: data/6011.jpg
#   inflating: data/6012.jpg
#   inflating: data/6013.jpg
#   inflating: data/6014.jpg
#   inflating: data/6015.jpg
#   inflating: data/6016.jpg
#   inflating: data/6017.jpg
#   inflating: data/6018.jpg
#   inflating: data/6019.jpg
#   inflating: data/602.jpg
#   inflating: data/6020.jpg
#   inflating: data/6021.jpg
#   inflating: data/6022.jpg
#   inflating: data/6023.jpg
#   inflating: data/6024.jpg
#   inflating: data/6025.jpg
#   inflating: data/6026.jpg
#   inflating: data/6027.jpg
#   inflating: data/6028.jpg
#   inflating: data/6029.jpg
#   inflating: data/603.jpg
#   inflating: data/6030.jpg
#   inflating: data/6031.jpg
#   inflating: data/6032.jpg
#   inflating: data/6033.jpg
#   inflating: data/6034.jpg
#   inflating: data/6035.jpg
#   inflating: data/6036.jpg
#   inflating: data/6037.jpg
#   inflating: data/6038.jpg
#   inflating: data/6039.jpg
#   inflating: data/604.jpg
#   inflating: data/6040.jpg
#   inflating: data/6041.jpg
#   inflating: data/6042.jpg
#   inflating: data/6043.jpg
#   inflating: data/6044.jpg
#   inflating: data/6045.jpg
#   inflating: data/6046.jpg
#   inflating: data/6047.jpg
#   inflating: data/6048.jpg
#   inflating: data/6049.jpg
#   inflating: data/605.jpg
#   inflating: data/6050.jpg
#   inflating: data/6051.jpg
#   inflating: data/6052.jpg
#   inflating: data/6053.jpg
#   inflating: data/6054.jpg
#   inflating: data/6055.jpg
#   inflating: data/6056.jpg
#   inflating: data/6057.jpg
#   inflating: data/6058.jpg
#   inflating: data/6059.jpg
#   inflating: data/606.jpg
#   inflating: data/6060.jpg
#   inflating: data/6061.jpg
#   inflating: data/6062.jpg
#   inflating: data/6063.jpg
#   inflating: data/6064.jpg
#   inflating: data/6065.jpg
#   inflating: data/6066.jpg
#   inflating: data/6067.jpg
#   inflating: data/6068.jpg
#   inflating: data/6069.jpg
#   inflating: data/607.jpg
#   inflating: data/6070.jpg
#   inflating: data/6071.jpg
#   inflating: data/6072.jpg
#   inflating: data/6073.jpg
#   inflating: data/6074.jpg
#   inflating: data/6075.jpg
#   inflating: data/6076.jpg
#   inflating: data/6077.jpg
#   inflating: data/6078.jpg
#   inflating: data/6079.jpg
#   inflating: data/608.jpg
#   inflating: data/6080.jpg
#   inflating: data/6081.jpg
#   inflating: data/6082.jpg
#   inflating: data/6083.jpg
#   inflating: data/6084.jpg
#   inflating: data/6085.jpg
#   inflating: data/6086.jpg
#   inflating: data/6087.jpg
#   inflating: data/6088.jpg
#   inflating: data/6089.jpg
#   inflating: data/609.jpg
#   inflating: data/6090.jpg
#   inflating: data/6091.jpg
#   inflating: data/6092.jpg
#   inflating: data/6093.jpg
#   inflating: data/6094.jpg
#   inflating: data/6095.jpg
#   inflating: data/6096.jpg
#   inflating: data/6097.jpg
#   inflating: data/6098.jpg
#   inflating: data/6099.jpg
#   inflating: data/61.jpg
#   inflating: data/610.jpg
#   inflating: data/6100.jpg
#   inflating: data/6101.jpg
#   inflating: data/6102.jpg
#   inflating: data/6103.jpg
#   inflating: data/6104.jpg
#   inflating: data/6105.jpg
#   inflating: data/6106.jpg
#   inflating: data/6107.jpg
#   inflating: data/6108.jpg
#   inflating: data/6109.jpg
#   inflating: data/611.jpg
#   inflating: data/6110.jpg
#   inflating: data/6111.jpg
#   inflating: data/6112.jpg
#   inflating: data/6113.jpg
#   inflating: data/6114.jpg
#   inflating: data/6115.jpg
#   inflating: data/6116.jpg
#   inflating: data/6117.jpg
#   inflating: data/6118.jpg
#   inflating: data/6119.jpg
#   inflating: data/612.jpg
#   inflating: data/6120.jpg
#   inflating: data/6121.jpg
#   inflating: data/6122.jpg
#   inflating: data/6123.jpg
#   inflating: data/6124.jpg
#   inflating: data/6125.jpg
#   inflating: data/6126.jpg
#   inflating: data/6127.jpg
#   inflating: data/6128.jpg
#   inflating: data/6129.jpg
#   inflating: data/613.jpg
#   inflating: data/6130.jpg
#   inflating: data/6131.jpg
#   inflating: data/6132.jpg
#   inflating: data/6133.jpg
#   inflating: data/6134.jpg
#   inflating: data/6135.jpg
#   inflating: data/6136.jpg
#   inflating: data/6137.jpg
#   inflating: data/6138.jpg
#   inflating: data/6139.jpg
#   inflating: data/614.jpg
#   inflating: data/6140.jpg
#   inflating: data/6141.jpg
#   inflating: data/6142.jpg
#   inflating: data/6143.jpg
#   inflating: data/6144.jpg
#   inflating: data/6145.jpg
#   inflating: data/6146.jpg
#   inflating: data/6147.jpg
#   inflating: data/6148.jpg
#   inflating: data/6149.jpg
#   inflating: data/615.jpg
#   inflating: data/6150.jpg
#   inflating: data/6151.jpg
#   inflating: data/6152.jpg
#   inflating: data/6153.jpg
#   inflating: data/6154.jpg
#   inflating: data/6155.jpg
#   inflating: data/6156.jpg
#   inflating: data/6157.jpg
#   inflating: data/6158.jpg
#   inflating: data/6159.jpg
#   inflating: data/616.jpg
#   inflating: data/6160.jpg
#   inflating: data/6161.jpg
#   inflating: data/6162.jpg
#   inflating: data/6163.jpg
#   inflating: data/6164.jpg
#   inflating: data/6165.jpg
#   inflating: data/6166.jpg
#   inflating: data/6167.jpg
#   inflating: data/6168.jpg
#   inflating: data/6169.jpg
#   inflating: data/617.jpg
#   inflating: data/6170.jpg
#   inflating: data/6171.jpg
#   inflating: data/6172.jpg
#   inflating: data/6173.jpg
#   inflating: data/6174.jpg
#   inflating: data/6175.jpg
#   inflating: data/6176.jpg
#   inflating: data/6177.jpg
#   inflating: data/6178.jpg
#   inflating: data/6179.jpg
#   inflating: data/618.jpg
#   inflating: data/6180.jpg
#   inflating: data/6181.jpg
#   inflating: data/6182.jpg
#   inflating: data/6183.jpg
#   inflating: data/6184.jpg
#   inflating: data/6185.jpg
#   inflating: data/6186.jpg
#   inflating: data/6187.jpg
#   inflating: data/6188.jpg
#   inflating: data/6189.jpg
#   inflating: data/619.jpg
#   inflating: data/6190.jpg
#   inflating: data/6191.jpg
#   inflating: data/6192.jpg
#   inflating: data/6193.jpg
#   inflating: data/6194.jpg
#   inflating: data/6195.jpg
#   inflating: data/6196.jpg
#   inflating: data/6197.jpg
#   inflating: data/6198.jpg
#   inflating: data/6199.jpg
#   inflating: data/62.jpg
#   inflating: data/620.jpg
#   inflating: data/6200.jpg
#   inflating: data/6201.jpg
#   inflating: data/6202.jpg
#   inflating: data/6203.jpg
#   inflating: data/6204.jpg
#   inflating: data/6205.jpg
#   inflating: data/6206.jpg
#   inflating: data/6207.jpg
#   inflating: data/6208.jpg
#   inflating: data/6209.jpg
#   inflating: data/621.jpg
#   inflating: data/6210.jpg
#   inflating: data/6211.jpg
#   inflating: data/6212.jpg
#   inflating: data/6213.jpg
#   inflating: data/6214.jpg
#   inflating: data/6215.jpg
#   inflating: data/6216.jpg
#   inflating: data/6217.jpg
#   inflating: data/6218.jpg
#   inflating: data/6219.jpg
#   inflating: data/622.jpg
#   inflating: data/6220.jpg
#   inflating: data/6221.jpg
#   inflating: data/6222.jpg
#   inflating: data/6223.jpg
#   inflating: data/6224.jpg
#   inflating: data/6225.jpg
#   inflating: data/6226.jpg
#   inflating: data/6227.jpg
#   inflating: data/6228.jpg
#   inflating: data/6229.jpg
#   inflating: data/623.jpg
#   inflating: data/6230.jpg
#   inflating: data/6231.jpg
#   inflating: data/6232.jpg
#   inflating: data/6233.jpg
#   inflating: data/6234.jpg
#   inflating: data/6235.jpg
#   inflating: data/6236.jpg
#   inflating: data/6237.jpg
#   inflating: data/6238.jpg
#   inflating: data/6239.jpg
#   inflating: data/624.jpg
#   inflating: data/6240.jpg
#   inflating: data/6241.jpg
#   inflating: data/6242.jpg
#   inflating: data/6243.jpg
#   inflating: data/6244.jpg
#   inflating: data/6245.jpg
#   inflating: data/6246.jpg
#   inflating: data/6247.jpg
#   inflating: data/6248.jpg
#   inflating: data/6249.jpg
#   inflating: data/625.jpg
#   inflating: data/6250.jpg
#   inflating: data/6251.jpg
#   inflating: data/6252.jpg
#   inflating: data/6253.jpg
#   inflating: data/6254.jpg
#   inflating: data/6255.jpg
#   inflating: data/6256.jpg
#   inflating: data/6257.jpg
#   inflating: data/6258.jpg
#   inflating: data/6259.jpg
#   inflating: data/626.jpg
#   inflating: data/6260.jpg
#   inflating: data/6261.jpg
#   inflating: data/6262.jpg
#   inflating: data/6263.jpg
#   inflating: data/6264.jpg
#   inflating: data/6265.jpg
#   inflating: data/6266.jpg
#   inflating: data/6267.jpg
#   inflating: data/6268.jpg
#   inflating: data/6269.jpg
#   inflating: data/627.jpg
#   inflating: data/6270.jpg
#   inflating: data/6271.jpg
#   inflating: data/6272.jpg
#   inflating: data/6273.jpg
#   inflating: data/6274.jpg
#   inflating: data/6275.jpg
#   inflating: data/6276.jpg
#   inflating: data/6277.jpg
#   inflating: data/6278.jpg
#   inflating: data/6279.jpg
#   inflating: data/628.jpg
#   inflating: data/6280.jpg
#   inflating: data/6281.jpg
#   inflating: data/6282.jpg
#   inflating: data/6283.jpg
#   inflating: data/6284.jpg
#   inflating: data/6285.jpg
#   inflating: data/6286.jpg
#   inflating: data/6287.jpg
#   inflating: data/6288.jpg
#   inflating: data/6289.jpg
#   inflating: data/629.jpg
#   inflating: data/6290.jpg
#   inflating: data/6291.jpg
#   inflating: data/6292.jpg
#   inflating: data/6293.jpg
#   inflating: data/6294.jpg
#   inflating: data/6295.jpg
#   inflating: data/6296.jpg
#   inflating: data/6297.jpg
#   inflating: data/6298.jpg
#   inflating: data/6299.jpg
#   inflating: data/63.jpg
#   inflating: data/630.jpg
#   inflating: data/6300.jpg
#   inflating: data/6301.jpg
#   inflating: data/6302.jpg
#   inflating: data/6303.jpg
#   inflating: data/6304.jpg
#   inflating: data/6305.jpg
#   inflating: data/6306.jpg
#   inflating: data/6307.jpg
#   inflating: data/6308.jpg
#   inflating: data/6309.jpg
#   inflating: data/631.jpg
#   inflating: data/6310.jpg
#   inflating: data/6311.jpg
#   inflating: data/6312.jpg
#   inflating: data/6313.jpg
#   inflating: data/6314.jpg
#   inflating: data/6315.jpg
#   inflating: data/6316.jpg
#   inflating: data/6317.jpg
#   inflating: data/6318.jpg
#   inflating: data/6319.jpg
#   inflating: data/632.jpg
#   inflating: data/6320.jpg
#   inflating: data/6321.jpg
#   inflating: data/6322.jpg
#   inflating: data/6323.jpg
#   inflating: data/6324.jpg
#   inflating: data/6325.jpg
#   inflating: data/6326.jpg
#   inflating: data/6327.jpg
#   inflating: data/6328.jpg
#   inflating: data/6329.jpg
#   inflating: data/633.jpg
#   inflating: data/6330.jpg
#   inflating: data/6331.jpg
#   inflating: data/6332.jpg
#   inflating: data/6333.jpg
#   inflating: data/6334.jpg
#   inflating: data/6335.jpg
#   inflating: data/6336.jpg
#   inflating: data/6337.jpg
#   inflating: data/6338.jpg
#   inflating: data/6339.jpg
#   inflating: data/634.jpg
#   inflating: data/6340.jpg
#   inflating: data/6341.jpg
#   inflating: data/6342.jpg
#   inflating: data/6343.jpg
#   inflating: data/6344.jpg
#   inflating: data/6345.jpg
#   inflating: data/6346.jpg
#   inflating: data/6347.jpg
#   inflating: data/6348.jpg
#   inflating: data/6349.jpg
#   inflating: data/635.jpg
#   inflating: data/6350.jpg
#   inflating: data/6351.jpg
#   inflating: data/6352.jpg
#   inflating: data/6353.jpg
#   inflating: data/6354.jpg
#   inflating: data/6355.jpg
#   inflating: data/6356.jpg
#   inflating: data/6357.jpg
#   inflating: data/6358.jpg
#   inflating: data/6359.jpg
#   inflating: data/636.jpg
#   inflating: data/6360.jpg
#   inflating: data/6361.jpg
#   inflating: data/6362.jpg
#   inflating: data/6363.jpg
#   inflating: data/6364.jpg
#   inflating: data/6365.jpg
#   inflating: data/6366.jpg
#   inflating: data/6367.jpg
#   inflating: data/6368.jpg
#   inflating: data/6369.jpg
#   inflating: data/637.jpg
#   inflating: data/6370.jpg
#   inflating: data/6371.jpg
#   inflating: data/6372.jpg
#   inflating: data/6373.jpg
#   inflating: data/6374.jpg
#   inflating: data/6375.jpg
#   inflating: data/6376.jpg
#   inflating: data/6377.jpg
#   inflating: data/6378.jpg
#   inflating: data/6379.jpg
#   inflating: data/638.jpg
#   inflating: data/6380.jpg
#   inflating: data/6381.jpg
#   inflating: data/6382.jpg
#   inflating: data/6383.jpg
#   inflating: data/6384.jpg
#   inflating: data/6385.jpg
#   inflating: data/6386.jpg
#   inflating: data/6387.jpg
#   inflating: data/6388.jpg
#   inflating: data/6389.jpg
#   inflating: data/639.jpg
#   inflating: data/6390.jpg
#   inflating: data/6391.jpg
#   inflating: data/6392.jpg
#   inflating: data/6393.jpg
#   inflating: data/6394.jpg
#   inflating: data/6395.jpg
#   inflating: data/6396.jpg
#   inflating: data/6397.jpg
#   inflating: data/6398.jpg
#   inflating: data/6399.jpg
#   inflating: data/64.jpg
#   inflating: data/640.jpg
#   inflating: data/6400.jpg
#   inflating: data/6401.jpg
#   inflating: data/6402.jpg
#   inflating: data/6403.jpg
#   inflating: data/6404.jpg
#   inflating: data/6405.jpg
#   inflating: data/6406.jpg
#   inflating: data/6407.jpg
#   inflating: data/6408.jpg
#   inflating: data/6409.jpg
#   inflating: data/641.jpg
#   inflating: data/6410.jpg
#   inflating: data/6411.jpg
#   inflating: data/6412.jpg
#   inflating: data/6413.jpg
#   inflating: data/6414.jpg
#   inflating: data/6415.jpg
#   inflating: data/6416.jpg
#   inflating: data/6417.jpg
#   inflating: data/6418.jpg
#   inflating: data/6419.jpg
#   inflating: data/642.jpg
#   inflating: data/6420.jpg
#   inflating: data/6421.jpg
#   inflating: data/6422.jpg
#   inflating: data/6423.jpg
#   inflating: data/6424.jpg
#   inflating: data/6425.jpg
#   inflating: data/6426.jpg
#   inflating: data/6427.jpg
#   inflating: data/6428.jpg
#   inflating: data/6429.jpg
#   inflating: data/643.jpg
#   inflating: data/6430.jpg
#   inflating: data/6431.jpg
#   inflating: data/6432.jpg
#   inflating: data/6433.jpg
#   inflating: data/6434.jpg
#   inflating: data/6435.jpg
#   inflating: data/6436.jpg
#   inflating: data/6437.jpg
#   inflating: data/6438.jpg
#   inflating: data/6439.jpg
#   inflating: data/644.jpg
#   inflating: data/6440.jpg
#   inflating: data/6441.jpg
#   inflating: data/6442.jpg
#   inflating: data/6443.jpg
#   inflating: data/6444.jpg
#   inflating: data/6445.jpg
#   inflating: data/6446.jpg
#   inflating: data/6447.jpg
#   inflating: data/6448.jpg
#   inflating: data/6449.jpg
#   inflating: data/645.jpg
#   inflating: data/6450.jpg
#   inflating: data/6451.jpg
#   inflating: data/6452.jpg
#   inflating: data/6453.jpg
#   inflating: data/6454.jpg
#   inflating: data/6455.jpg
#   inflating: data/6456.jpg
#   inflating: data/6457.jpg
#   inflating: data/6458.jpg
#   inflating: data/6459.jpg
#   inflating: data/646.jpg
#   inflating: data/6460.jpg
#   inflating: data/6461.jpg
#   inflating: data/6462.jpg
#   inflating: data/6463.jpg
#   inflating: data/6464.jpg
#   inflating: data/6465.jpg
#   inflating: data/6466.jpg
#   inflating: data/6467.jpg
#   inflating: data/6468.jpg
#   inflating: data/6469.jpg
#   inflating: data/647.jpg
#   inflating: data/6470.jpg
#   inflating: data/6471.jpg
#   inflating: data/6472.jpg
#   inflating: data/6473.jpg
#   inflating: data/6474.jpg
#   inflating: data/6475.jpg
#   inflating: data/6476.jpg
#   inflating: data/6477.jpg
#   inflating: data/6478.jpg
#   inflating: data/6479.jpg
#   inflating: data/648.jpg
#   inflating: data/6480.jpg
#   inflating: data/6481.jpg
#   inflating: data/6482.jpg
#   inflating: data/6483.jpg
#   inflating: data/6484.jpg
#   inflating: data/6485.jpg
#   inflating: data/6486.jpg
#   inflating: data/6487.jpg
#   inflating: data/6488.jpg
#   inflating: data/6489.jpg
#   inflating: data/649.jpg
#   inflating: data/6490.jpg
#   inflating: data/6491.jpg
#   inflating: data/6492.jpg
#   inflating: data/6493.jpg
#   inflating: data/6494.jpg
#   inflating: data/6495.jpg
#   inflating: data/6496.jpg
#   inflating: data/6497.jpg
#   inflating: data/6498.jpg
#   inflating: data/6499.jpg
#   inflating: data/65.jpg
#   inflating: data/650.jpg
#   inflating: data/6500.jpg
#   inflating: data/6501.jpg
#   inflating: data/6502.jpg
#   inflating: data/6503.jpg
#   inflating: data/6504.jpg
#   inflating: data/6505.jpg
#   inflating: data/6506.jpg
#   inflating: data/6507.jpg
#   inflating: data/6508.jpg
#   inflating: data/6509.jpg
#   inflating: data/651.jpg
#   inflating: data/6510.jpg
#   inflating: data/6511.jpg
#   inflating: data/6512.jpg
#   inflating: data/6513.jpg
#   inflating: data/6514.jpg
#   inflating: data/6515.jpg
#   inflating: data/6516.jpg
#   inflating: data/6517.jpg
#   inflating: data/6518.jpg
#   inflating: data/6519.jpg
#   inflating: data/652.jpg
#   inflating: data/6520.jpg
#   inflating: data/6521.jpg
#   inflating: data/6522.jpg
#   inflating: data/6523.jpg
#   inflating: data/6524.jpg
#   inflating: data/6525.jpg
#   inflating: data/6526.jpg
#   inflating: data/6527.jpg
#   inflating: data/6528.jpg
#   inflating: data/6529.jpg
#   inflating: data/653.jpg
#   inflating: data/6530.jpg
#   inflating: data/6531.jpg
#   inflating: data/6532.jpg
#   inflating: data/6533.jpg
#   inflating: data/6534.jpg
#   inflating: data/6535.jpg
#   inflating: data/6536.jpg
#   inflating: data/6537.jpg
#   inflating: data/6538.jpg
#   inflating: data/6539.jpg
#   inflating: data/654.jpg
#   inflating: data/6540.jpg
#   inflating: data/6541.jpg
#   inflating: data/6542.jpg
#   inflating: data/6543.jpg
#   inflating: data/6544.jpg
#   inflating: data/6545.jpg
#   inflating: data/6546.jpg
#   inflating: data/6547.jpg
#   inflating: data/6548.jpg
#   inflating: data/6549.jpg
#   inflating: data/655.jpg
#   inflating: data/6550.jpg
#   inflating: data/6551.jpg
#   inflating: data/6552.jpg
#   inflating: data/6553.jpg
#   inflating: data/6554.jpg
#   inflating: data/6555.jpg
#   inflating: data/6556.jpg
#   inflating: data/6557.jpg
#   inflating: data/6558.jpg
#   inflating: data/6559.jpg
#   inflating: data/656.jpg
#   inflating: data/6560.jpg
#   inflating: data/6561.jpg
#   inflating: data/6562.jpg
#   inflating: data/6563.jpg
#   inflating: data/6564.jpg
#   inflating: data/6565.jpg
#   inflating: data/6566.jpg
#   inflating: data/6567.jpg
#   inflating: data/6568.jpg
#   inflating: data/6569.jpg
#   inflating: data/657.jpg
#   inflating: data/6570.jpg
#   inflating: data/6571.jpg
#   inflating: data/6572.jpg
#   inflating: data/6573.jpg
#   inflating: data/6574.jpg
#   inflating: data/6575.jpg
#   inflating: data/6576.jpg
#   inflating: data/6577.jpg
#   inflating: data/6578.jpg
#   inflating: data/6579.jpg
#   inflating: data/658.jpg
#   inflating: data/6580.jpg
#   inflating: data/6581.jpg
#   inflating: data/6582.jpg
#   inflating: data/6583.jpg
#   inflating: data/6584.jpg
#   inflating: data/6585.jpg
#   inflating: data/6586.jpg
#   inflating: data/6587.jpg
#   inflating: data/6588.jpg
#   inflating: data/6589.jpg
#   inflating: data/659.jpg
#   inflating: data/6590.jpg
#   inflating: data/6591.jpg
#   inflating: data/6592.jpg
#   inflating: data/6593.jpg
#   inflating: data/6594.jpg
#   inflating: data/6595.jpg
#   inflating: data/6596.jpg
#   inflating: data/6597.jpg
#   inflating: data/6598.jpg
#   inflating: data/6599.jpg
#   inflating: data/66.jpg
#   inflating: data/660.jpg
#   inflating: data/6600.jpg
#   inflating: data/6601.jpg
#   inflating: data/6602.jpg
#   inflating: data/6603.jpg
#   inflating: data/6604.jpg
#   inflating: data/6605.jpg
#   inflating: data/6606.jpg
#   inflating: data/6607.jpg
#   inflating: data/6608.jpg
#   inflating: data/6609.jpg
#   inflating: data/661.jpg
#   inflating: data/6610.jpg
#   inflating: data/6611.jpg
#   inflating: data/6612.jpg
#   inflating: data/6613.jpg
#   inflating: data/6614.jpg
#   inflating: data/6615.jpg
#   inflating: data/6616.jpg
#   inflating: data/6617.jpg
#   inflating: data/6618.jpg
#   inflating: data/6619.jpg
#   inflating: data/662.jpg
#   inflating: data/6620.jpg
#   inflating: data/6621.jpg
#   inflating: data/6622.jpg
#   inflating: data/6623.jpg
#   inflating: data/6624.jpg
#   inflating: data/6625.jpg
#   inflating: data/6626.jpg
#   inflating: data/6627.jpg
#   inflating: data/6628.jpg
#   inflating: data/6629.jpg
#   inflating: data/663.jpg
#   inflating: data/6630.jpg
#   inflating: data/6631.jpg
#   inflating: data/6632.jpg
#   inflating: data/6633.jpg
#   inflating: data/6634.jpg
# ...
#   inflating: data/9621.jpg
#   inflating: data/9622.jpg
#   inflating: data/9623.jpg
#   inflating: data/9624.jpg
#   inflating: data/9625.jpg
#   inflating: data/9626.jpg
#   inflating: data/9627.jpg
#   inflating: data/9628.jpg
#   inflating: data/9629.jpg
#   inflating: data/963.jpg
#   inflating: data/9630.jpg
#   inflating: data/9631.jpg
#   inflating: data/9632.jpg
#   inflating: data/9633.jpg
#   inflating: data/9634.jpg
#   inflating: data/9635.jpg
#   inflating: data/9636.jpg
#   inflating: data/9637.jpg
#   inflating: data/9638.jpg
#   inflating: data/9639.jpg
#   inflating: data/964.jpg
#   inflating: data/9640.jpg
#   inflating: data/9641.jpg
#   inflating: data/9642.jpg
#   inflating: data/9643.jpg
#   inflating: data/9644.jpg
#   inflating: data/9645.jpg
#   inflating: data/9646.jpg
#   inflating: data/9647.jpg
#   inflating: data/9648.jpg
#   inflating: data/9649.jpg
#   inflating: data/965.jpg
#   inflating: data/9650.jpg
#   inflating: data/9651.jpg
#   inflating: data/9652.jpg
#   inflating: data/9653.jpg
#   inflating: data/9654.jpg
#   inflating: data/9655.jpg
#   inflating: data/9656.jpg
#   inflating: data/9657.jpg
#   inflating: data/9658.jpg
#   inflating: data/9659.jpg
#   inflating: data/966.jpg
#   inflating: data/9660.jpg
#   inflating: data/9661.jpg
#   inflating: data/9662.jpg
#   inflating: data/9663.jpg
#   inflating: data/9664.jpg
#   inflating: data/9665.jpg
#   inflating: data/9666.jpg
#   inflating: data/9667.jpg
#   inflating: data/9668.jpg
#   inflating: data/9669.jpg
#   inflating: data/967.jpg
#   inflating: data/9670.jpg
#   inflating: data/9671.jpg
#   inflating: data/9672.jpg
#   inflating: data/9673.jpg
#   inflating: data/9674.jpg
#   inflating: data/9675.jpg
#   inflating: data/9676.jpg
#   inflating: data/9677.jpg
#   inflating: data/9678.jpg
#   inflating: data/9679.jpg
#   inflating: data/968.jpg
#   inflating: data/9680.jpg
#   inflating: data/9681.jpg
#   inflating: data/9682.jpg
#   inflating: data/9683.jpg
#   inflating: data/9684.jpg
#   inflating: data/9685.jpg
#   inflating: data/9686.jpg
#   inflating: data/9687.jpg
#   inflating: data/9688.jpg
#   inflating: data/9689.jpg
#   inflating: data/969.jpg
#   inflating: data/9690.jpg
#   inflating: data/9691.jpg
#   inflating: data/9692.jpg
#   inflating: data/9693.jpg
#   inflating: data/9694.jpg
#   inflating: data/9695.jpg
#   inflating: data/9696.jpg
#   inflating: data/9697.jpg
#   inflating: data/9698.jpg
#   inflating: data/9699.jpg
#   inflating: data/97.jpg
#   inflating: data/970.jpg
#   inflating: data/9700.jpg
#   inflating: data/9701.jpg
#   inflating: data/9702.jpg
#   inflating: data/9703.jpg
#   inflating: data/9704.jpg
#   inflating: data/9705.jpg
#   inflating: data/9706.jpg
#   inflating: data/9707.jpg
#   inflating: data/9708.jpg
#   inflating: data/9709.jpg
#   inflating: data/971.jpg
#   inflating: data/9710.jpg
#   inflating: data/9711.jpg
#   inflating: data/9712.jpg
#   inflating: data/9713.jpg
#   inflating: data/9714.jpg
#   inflating: data/9715.jpg
#   inflating: data/9716.jpg
#   inflating: data/9717.jpg
#   inflating: data/9718.jpg
#   inflating: data/9719.jpg
#   inflating: data/972.jpg
#   inflating: data/9720.jpg
#   inflating: data/9721.jpg
#   inflating: data/9722.jpg
#   inflating: data/9723.jpg
#   inflating: data/9724.jpg
#   inflating: data/9725.jpg
#   inflating: data/9726.jpg
#   inflating: data/9727.jpg
#   inflating: data/9728.jpg
#   inflating: data/9729.jpg
#   inflating: data/973.jpg
#   inflating: data/9730.jpg
#   inflating: data/9731.jpg
#   inflating: data/9732.jpg
#   inflating: data/9733.jpg
#   inflating: data/9734.jpg
#   inflating: data/9735.jpg
#   inflating: data/9736.jpg
#   inflating: data/9737.jpg
#   inflating: data/9738.jpg
#   inflating: data/9739.jpg
#   inflating: data/974.jpg
#   inflating: data/9740.jpg
#   inflating: data/9741.jpg
#   inflating: data/9742.jpg
#   inflating: data/9743.jpg
#   inflating: data/9744.jpg
#   inflating: data/9745.jpg
#   inflating: data/9746.jpg
#   inflating: data/9747.jpg
#   inflating: data/9748.jpg
#   inflating: data/9749.jpg
#   inflating: data/975.jpg
#   inflating: data/9750.jpg
#   inflating: data/9751.jpg
#   inflating: data/9752.jpg
#   inflating: data/9753.jpg
#   inflating: data/9754.jpg
#   inflating: data/9755.jpg
#   inflating: data/9756.jpg
#   inflating: data/9757.jpg
#   inflating: data/9758.jpg
#   inflating: data/9759.jpg
#   inflating: data/976.jpg
#   inflating: data/9760.jpg
#   inflating: data/9761.jpg
#   inflating: data/9762.jpg
#   inflating: data/9763.jpg
#   inflating: data/9764.jpg
#   inflating: data/9765.jpg
#   inflating: data/9766.jpg
#   inflating: data/9767.jpg
#   inflating: data/9768.jpg
#   inflating: data/9769.jpg
#   inflating: data/977.jpg
#   inflating: data/9770.jpg
#   inflating: data/9771.jpg
#   inflating: data/9772.jpg
#   inflating: data/9773.jpg
#   inflating: data/9774.jpg
#   inflating: data/9775.jpg
#   inflating: data/9776.jpg
#   inflating: data/9777.jpg
#   inflating: data/9778.jpg
#   inflating: data/9779.jpg
#   inflating: data/978.jpg
#   inflating: data/9780.jpg
#   inflating: data/9781.jpg
#   inflating: data/9782.jpg
#   inflating: data/9783.jpg
#   inflating: data/9784.jpg
#   inflating: data/9785.jpg
#   inflating: data/9786.jpg
#   inflating: data/9787.jpg
#   inflating: data/9788.jpg
#   inflating: data/9789.jpg
#   inflating: data/979.jpg
#   inflating: data/9790.jpg
#   inflating: data/9791.jpg
#   inflating: data/9792.jpg
#   inflating: data/9793.jpg
#   inflating: data/9794.jpg
#   inflating: data/9795.jpg
#   inflating: data/9796.jpg
#   inflating: data/9797.jpg
#   inflating: data/9798.jpg
#   inflating: data/9799.jpg
#   inflating: data/98.jpg
#   inflating: data/980.jpg
#   inflating: data/9800.jpg
#   inflating: data/9801.jpg
#   inflating: data/9802.jpg
#   inflating: data/9803.jpg
#   inflating: data/9804.jpg
#   inflating: data/9805.jpg
#   inflating: data/9806.jpg
#   inflating: data/9807.jpg
#   inflating: data/9808.jpg
#   inflating: data/9809.jpg
#   inflating: data/981.jpg
#   inflating: data/9810.jpg
#   inflating: data/9811.jpg
#   inflating: data/9812.jpg
#   inflating: data/9813.jpg
#   inflating: data/9814.jpg
#   inflating: data/9815.jpg
#   inflating: data/9816.jpg
#   inflating: data/9817.jpg
#   inflating: data/9818.jpg
#   inflating: data/9819.jpg
#   inflating: data/982.jpg
#   inflating: data/9820.jpg
#   inflating: data/9821.jpg
#   inflating: data/9822.jpg
#   inflating: data/9823.jpg
#   inflating: data/9824.jpg
#   inflating: data/9825.jpg
#   inflating: data/9826.jpg
#   inflating: data/9827.jpg
#   inflating: data/9828.jpg
#   inflating: data/9829.jpg
#   inflating: data/983.jpg
#   inflating: data/9830.jpg
#   inflating: data/9831.jpg
#   inflating: data/9832.jpg
#   inflating: data/9833.jpg
#   inflating: data/9834.jpg
#   inflating: data/9835.jpg
#   inflating: data/9836.jpg
#   inflating: data/9837.jpg
#   inflating: data/9838.jpg
#   inflating: data/9839.jpg
#   inflating: data/984.jpg
#   inflating: data/9840.jpg
#   inflating: data/9841.jpg
#   inflating: data/9842.jpg
#   inflating: data/9843.jpg
#   inflating: data/9844.jpg
#   inflating: data/9845.jpg
#   inflating: data/9846.jpg
#   inflating: data/9847.jpg
#   inflating: data/9848.jpg
#   inflating: data/9849.jpg
#   inflating: data/985.jpg
#   inflating: data/9850.jpg
#   inflating: data/9851.jpg
#   inflating: data/9852.jpg
#   inflating: data/9853.jpg
#   inflating: data/9854.jpg
#   inflating: data/9855.jpg
#   inflating: data/9856.jpg
#   inflating: data/9857.jpg
#   inflating: data/9858.jpg
#   inflating: data/9859.jpg
#   inflating: data/986.jpg
#   inflating: data/9860.jpg
#   inflating: data/9861.jpg
#   inflating: data/9862.jpg
#   inflating: data/9863.jpg
#   inflating: data/9864.jpg
#   inflating: data/9865.jpg
#   inflating: data/9866.jpg
#   inflating: data/9867.jpg
#   inflating: data/9868.jpg
#   inflating: data/9869.jpg
#   inflating: data/987.jpg
#   inflating: data/9870.jpg
#   inflating: data/9871.jpg
#   inflating: data/9872.jpg
#   inflating: data/9873.jpg
#   inflating: data/9874.jpg
#   inflating: data/9875.jpg
#   inflating: data/9876.jpg
#   inflating: data/9877.jpg
#   inflating: data/9878.jpg
#   inflating: data/9879.jpg
#   inflating: data/988.jpg
#   inflating: data/9880.jpg
#   inflating: data/9881.jpg
#   inflating: data/9882.jpg
#   inflating: data/9883.jpg
#   inflating: data/9884.jpg
#   inflating: data/9885.jpg
#   inflating: data/9886.jpg
#   inflating: data/9887.jpg
#   inflating: data/9888.jpg
#   inflating: data/9889.jpg
#   inflating: data/989.jpg
#   inflating: data/9890.jpg
#   inflating: data/9891.jpg
#   inflating: data/9892.jpg
#   inflating: data/9893.jpg
#   inflating: data/9894.jpg
#   inflating: data/9895.jpg
#   inflating: data/9896.jpg
#   inflating: data/9897.jpg
#   inflating: data/9898.jpg
#   inflating: data/9899.jpg
#   inflating: data/99.jpg
#   inflating: data/990.jpg
#   inflating: data/9900.jpg
#   inflating: data/9901.jpg
#   inflating: data/9902.jpg
#   inflating: data/9903.jpg
#   inflating: data/9904.jpg
#   inflating: data/9905.jpg
#   inflating: data/9906.jpg
#   inflating: data/9907.jpg
#   inflating: data/9908.jpg
#   inflating: data/9909.jpg
#   inflating: data/991.jpg
#   inflating: data/9910.jpg
#   inflating: data/9911.jpg
#   inflating: data/9912.jpg
#   inflating: data/9913.jpg
#   inflating: data/9914.jpg
#   inflating: data/9915.jpg
#   inflating: data/9916.jpg
#   inflating: data/9917.jpg
#   inflating: data/9918.jpg
#   inflating: data/9919.jpg
#   inflating: data/992.jpg
#   inflating: data/9920.jpg
#   inflating: data/9921.jpg
#   inflating: data/9922.jpg
#   inflating: data/9923.jpg
#   inflating: data/9924.jpg
#   inflating: data/9925.jpg
#   inflating: data/9926.jpg
#   inflating: data/9927.jpg
#   inflating: data/9928.jpg
#   inflating: data/9929.jpg
#   inflating: data/993.jpg
#   inflating: data/9930.jpg
#   inflating: data/9931.jpg
#   inflating: data/9932.jpg
#   inflating: data/9933.jpg
#   inflating: data/9934.jpg
#   inflating: data/9935.jpg
#   inflating: data/9936.jpg
#   inflating: data/9937.jpg
#   inflating: data/9938.jpg
#   inflating: data/9939.jpg
#   inflating: data/994.jpg
#   inflating: data/9940.jpg
#   inflating: data/9941.jpg
#   inflating: data/9942.jpg
#   inflating: data/9943.jpg
#   inflating: data/9944.jpg
#   inflating: data/9945.jpg
#   inflating: data/9946.jpg
#   inflating: data/9947.jpg
#   inflating: data/9948.jpg
#   inflating: data/9949.jpg
#   inflating: data/995.jpg
#   inflating: data/9950.jpg
#   inflating: data/9951.jpg
#   inflating: data/9952.jpg
#   inflating: data/9953.jpg
#   inflating: data/9954.jpg
#   inflating: data/9955.jpg
#   inflating: data/9956.jpg
#   inflating: data/9957.jpg
#   inflating: data/9958.jpg
#   inflating: data/9959.jpg
#   inflating: data/996.jpg
#   inflating: data/9960.jpg
#   inflating: data/9961.jpg
#   inflating: data/9962.jpg
#   inflating: data/9963.jpg
#   inflating: data/9964.jpg
#   inflating: data/9965.jpg
#   inflating: data/9966.jpg
#   inflating: data/9967.jpg
#   inflating: data/9968.jpg
#   inflating: data/9969.jpg
#   inflating: data/997.jpg
#   inflating: data/9970.jpg
#   inflating: data/9971.jpg
#   inflating: data/9972.jpg
#   inflating: data/9973.jpg
#   inflating: data/9974.jpg
#   inflating: data/9975.jpg
#   inflating: data/9976.jpg
#   inflating: data/9977.jpg
#   inflating: data/9978.jpg
#   inflating: data/9979.jpg
#   inflating: data/998.jpg
#   inflating: data/9980.jpg
#   inflating: data/9981.jpg
#   inflating: data/9982.jpg
#   inflating: data/9983.jpg
#   inflating: data/9984.jpg
#   inflating: data/9985.jpg
#   inflating: data/9986.jpg
#   inflating: data/9987.jpg
#   inflating: data/9988.jpg
#   inflating: data/9989.jpg
#   inflating: data/999.jpg
#   inflating: data/9990.jpg
#   inflating: data/9991.jpg
#   inflating: data/9992.jpg
#   inflating: data/9993.jpg
#   inflating: data/9994.jpg
#   inflating: data/9995.jpg
#   inflating: data/9996.jpg
#   inflating: data/9997.jpg
#   inflating: data/9998.jpg
#   inflating: data/9999.jpg
#   inflating: test.csv
#   inflating: train.csv

# %% [markdown]
# ### **2.2 Data Preprocessing**
#
# We will use natural language processing technologies like Punctuation removal, Stopwords removal and Wrong spell, Case-folding, Lemmatization, Tokenization, Word Embedding, Padding and Word Embedding (pretrained model like "glove-twitter-100") for the Caption Preprocess.

# %%
# prepare train，validation set 

train_path = './train.csv'
test_path = './test.csv'
emb_model = api.load("glove-twitter-100") 
input_dim = emb_model.vector_size

traImageId,train_captions_list,traLable,testImageId,testCaption = nlp_process(train_path, test_path,label_nums,emb_model)
train_id, val_id, train_caption, val_caption, train_label, val_label = train_test_split(np.array(traImageId), 
                                                                                        np.array(train_captions_list, np.float32), 
                                                                                        np.array(traLable), 
                                                                                        test_size=VALIDATION_RATIO, shuffle=True)
# Out:
# [==================================================] 100.0% 387.1/387.1MB downloaded

# %% [markdown]
# ### **2.3 Input preparation**
#
# We prepare the model input in this section.
# The output of this section will splitted to three part, which are train_data, val_data and test_data.

# %%
# Map-style datasets
# https://pytorch.org/docs/stable/data.html?highlight=dataset#map-style-datasets
class my_Data_Set(nn.Module):
    def __init__(self, flag, transform=None, loader=None):
        super(my_Data_Set, self).__init__()

        self.flag = flag
        if flag == 'train':
            self.images = train_id.tolist()
            self.caption = torch.from_numpy(train_caption)
            self.labels = train_label.tolist()
        elif flag == 'val':
            self.images = val_id.tolist()
            self.caption = torch.from_numpy(val_caption)
            self.labels = val_label.tolist()
        elif flag == 'test':
            self.images = testImageId
            self.caption = torch.from_numpy(testCaption)

        self.transform = transform
        self.loader = loader

    # rewrite this function to acquire data
    def __getitem__(self, item):
        # obtain the image_id
        imageName = self.images[item]
        # get image
        image = self.loader(imageName)
        # do transform
        if self.transform is not None:
            image = self.transform(image)
        # get captions
        caption = self.caption[item]

        # get labels
        if not self.flag == 'test':
            label = self.labels[item]
            # do label into folat for BCE
            label = torch.FloatTensor(label)
            return image, caption, label
        # only test can have labels
        else:
            return image, caption
 
    # get the length
    def __len__(self):
        return len(self.images)


# use the dataloader to get data
train_data = my_Data_Set(flag='train', transform=image_transforms['train'], loader=load_image)
val_data = my_Data_Set(flag='val', transform=image_transforms['val'], loader=load_image)
test_data = my_Data_Set(flag='test', transform=image_transforms['val'], loader=load_image)

train_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True, **kwargs)
val_dataloader = DataLoader(val_data, batch_size=BATCH_SIZE, **kwargs)
test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE, **kwargs)

dataloaders = {'train': train_dataloader, 'val': val_dataloader, 'test': test_dataloader}
# use the len function to get information to put in model
dataset_sizes = {'train': train_data.__len__(), 'val': val_data.__len__(), 'test': test_data.__len__()}

# %% [markdown]
# ### **2.4 Training Functions**
#
# The training procedure will be:
#
# train_model(): iterate process including training and validating
#
# train_epoch(): one training epoch process
#
# val_epoch(): one validating epoch process
#
# train_iter(): single iteration for one batch
#
# calculate_acuracy(): return current precision and recall
#
# predict():predict the labels of test data.

# %%
# calculate the accuracy rate
def calculate_acuracy(model_pred, labels):

    # Threshold to make sure the label got a baseline 
    pred_result = model_pred > THRESHOLD
    pred_result = pred_result.float()
    pred_one_num = torch.sum(pred_result)
    #  no label means no accuracy
    if pred_one_num == 0:
        return 0, 0
    # nums of true labels we predict
    target_one_num = torch.sum(labels)
    # nums of true labels
    true_predict_num = torch.sum(pred_result * labels)
    # calculate precision
    precision = true_predict_num / pred_one_num
    # calculate recall
    recall = true_predict_num / target_one_num
 
    return precision.item(), recall.item()


def train_iter(model, device, optimizer, criterion, images, captions, targets):

    #  use gpu
    images, captions, targets = images.to(device), captions.to(device), targets.to(device)
    # initialize the gradient
    optimizer.zero_grad()
    # do training
    outputs = model(images, captions)
    # BCE to do loss
    loss = criterion(outputs, targets)
    # get recall and precision
    precision, recall = calculate_acuracy(outputs, targets)
    # do backward
    loss.backward()
    # Update the parameters
    optimizer.step()
    return loss, precision, recall


def train_epoch(model, device, dataloader, optimizer, criterion, scheduler, running_loss, running_precision, running_recall, batch_num):

    # do training
    model.train()
    for data in dataloader:
        # get the dataloader to get data
        images, captions, targets = data
        loss, precision, recall = train_iter(model, device, optimizer, criterion, images, captions, targets)
        # get loss and recall precision
        running_loss += loss.item() * images.size(0)
        running_precision += precision
        running_recall += recall
        batch_num += 1
    # change learn rate
    scheduler.step()
    return running_loss, running_precision, running_recall, batch_num


def val_epoch(model, device, dataloader, criterion, running_loss, running_precision, running_recall, batch_num):

    # do on evaluation (the test part)
    model.eval()
    # initialization on gradient
    with torch.no_grad():
        for data in dataloader:
            # from gpu or cup to get data
            images, captions, targets = data
            images, captions, targets = images.to(device), captions.to(device), targets.to(device)
            # start forward
            outputs = model(images, captions)
            # use BCE to get loss
            loss = criterion(outputs, targets)
            # get loss and accuracy
            running_loss += loss.item() * images.size(0)
            precision, recall = calculate_acuracy(outputs, targets)
            running_precision += precision
            running_recall += recall
            batch_num += 1  
    return running_loss, running_precision, running_recall, batch_num


def train_model(model, device, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()
    # start the epoch by the setting epoch nums
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        # in each epoch do things on training and valuation dataset
        for phase in ['train', 'val']:
            # do initialization before each epoch
            running_loss = 0.0
            running_precision = 0.0
            running_recall = 0.0
            batch_num = 0

            if phase == 'train':
                running_loss, running_precision, running_recall, batch_num = train_epoch(model, device, dataloaders[phase], optimizer, criterion, scheduler, running_loss, running_precision, running_recall, batch_num)
            elif phase == 'val':
                running_loss, running_precision, running_recall, batch_num = val_epoch(model, device, dataloaders[phase], criterion, running_loss, running_precision, running_recall, batch_num)
        
            # based on size to mean the loss and running precision
            epoch_loss = running_loss / dataset_sizes[phase]
            print('{:5} Loss: {:.4f} '.format(phase, epoch_loss), end=' ')
            epoch_precision = running_precision / batch_num
            print('{:5} Precision: {:.4f} '.format(phase, epoch_precision), end=' ')
            epoch_recall = running_recall / batch_num
            print('{:5} Recall: {:.4f} '.format(phase, epoch_recall), end=' ')
            mean_f1_score = 2 * epoch_precision * epoch_recall / (epoch_precision + epoch_recall)
            print('{:5} F1_score: {:.4f}'.format(phase, mean_f1_score))
            # just put each epoch into file 
            torch.save(model, 'The_'+ str(epoch + 1) + '_epoch_model.pt')
    time_cost = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_cost // 60, time_cost % 60))


def predict(model, device, dataloader=dataloaders['test']):

    # evaluation the model
    model.eval()
    predicted = torch.tensor([])
    # initialization the gradient
    with torch.no_grad():
        for data in dataloader:
            # get dataloader
            images, captions = data
            images, captions = images.to(device), captions.to(device)
            # do training
            output = model(images, captions)
            predicted = torch.cat((predicted, output.cpu()), 0)
    return predicted

# %% [markdown]
# ### **3.1 Defining and training Model**
#
# Implementing image classification model with densenet model framework and transformer.
# The model is a combination of Multi-head Self-Attention Transformer and DenseNet16. After training with the best hyper-parameter, the highest accuracy of the final model was 0.8516 on the training
# set, and it took six minutes to evaluate the training of an Epoch

# %%
class MixNet(nn.Module):
    def __init__(self):

        super(MixNet, self).__init__()
        
        # Building densenet framework layer
        # Referred from https://pytorch.org/vision/stable/generated/torchvision.models.densenet169.html
        self.densenet = models.densenet169(pretrained = True, progress = False, memory_efficient = False)
        
        # Obtain the number of image features
        image_features_num = self.densenet.classifier.in_features

        # Implementation of densenet framework
        self.densenet.classifier = nn.Linear(image_features_num, 64)
        
        # Building Transformer layer (5 layers number)
        encoder_layer = nn.TransformerEncoderLayer(d_model=input_dim, nhead=5, dropout = DROPOUT)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=5)

        # To get the output of encoder_layer
        self.trans_linear = nn.Linear(SEQUENCE_LENGTH * input_dim, 64)
        
        # Building Concatenating layer
        self.linear = nn.Linear(64*2, label_nums)
        self.sigmoid = nn.Sigmoid()

    def forward(self, image, caption):
        """
        :param image: image data vector generated in the preprocessing stage
        :param caption: caption data vector generated in the preprocessing stage
        """  
        # Obtain the features of image
        densenet_output = self.densenet(image)

        # Obtain the output of transformer (Using transpose to temporarily fit transformer framework)
        caption = caption.transpose(1, 0)
        encoder_out = self.transformer_encoder(caption).transpose(1, 0)

        # flatten the output of transformer
        trans_out = self.trans_linear(torch.flatten(encoder_out, start_dim=1, end_dim=-1))
        
        # concatenate the output of densenet framework and transformer architecture
        output_concate = self.linear(torch.cat((densenet_output, trans_out), 1))

        # Limit the output to 0-1
        output_final = self.sigmoid(output_concate)
        return output_final

# %% [markdown]
# The implementation of the experiment, in this part, we will train the model and find the optimal model by tuning the parameters

# %%
model = MixNet().to(device)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

train_model(model, device, criterion=criterion, optimizer=optimizer, scheduler=scheduler, num_epochs=NUM_EPOCHS)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet169-b2777c0a.pth" to /root/.cache/torch/hub/checkpoints/densenet169-b2777c0a.pth
# Epoch 1/7
# train Loss: 0.1263  train Precision: 0.7541  train Recall: 0.6881  train F1_score: 0.7196
# val   Loss: 0.0828  val   Precision: 0.7923  val   Recall: 0.8080  val   F1_score: 0.8001
# -----------------------------------------------------------------------------------------
# Epoch 2/7
# train Loss: 0.0819  train Precision: 0.8166  train Recall: 0.7989  train F1_score: 0.8076
# val   Loss: 0.0742  val   Precision: 0.8238  val   Recall: 0.8205  val   F1_score: 0.8221
# -----------------------------------------------------------------------------------------
# Epoch 3/7
# train Loss: 0.0748  train Precision: 0.8328  train Recall: 0.8147  train F1_score: 0.8237
# val   Loss: 0.0724  val   Precision: 0.8147  val   Recall: 0.8312  val   F1_score: 0.8229
# -----------------------------------------------------------------------------------------
# Epoch 4/7
# train Loss: 0.0704  train Precision: 0.8421  train Recall: 0.8252  train F1_score: 0.8336
# val   Loss: 0.0705  val   Precision: 0.8309  val   Recall: 0.8289  val   F1_score: 0.8299
# -----------------------------------------------------------------------------------------
# Epoch 5/7
# train Loss: 0.0666  train Precision: 0.8517  train Recall: 0.8328  train F1_score: 0.8421
# val   Loss: 0.0697  val   Precision: 0.8244  val   Recall: 0.8306  val   F1_score: 0.8275
# -----------------------------------------------------------------------------------------
# Epoch 6/7
# train Loss: 0.0636  train Precision: 0.8581  train Recall: 0.8411  train F1_score: 0.8495
# val   Loss: 0.0690  val   Precision: 0.8101  val   Recall: 0.8464  val   F1_score: 0.8279
# -----------------------------------------------------------------------------------------
# Epoch 7/7
# train Loss: 0.0604  train Precision: 0.8609  train Recall: 0.8513  train F1_score: 0.8560
# val   Loss: 0.0681  val   Precision: 0.8501  val   Recall: 0.8344  val   F1_score: 0.8422
# -----------------------------------------------------------------------------------------
# Training complete in 38m 9s

# %% [markdown]
# ### **3.2 Predicting**
#
# Making prediction using test data and exporting Predicted_labels file

# %%
# load model
model = torch.load('The_7_epoch_model.pt')

# predict labels on test data set
predicted_results = predict(model, device, dataloader=dataloaders['test'])

# Save the predictation results in colab
with open('Predicted_labels.txt', 'w') as f:
    f.write('ImageID,Labels\n')
    for x1, x2 in enumerate(predicted_results):
        line = x2 > 0.3
        pred = [i for i in range(len(line)) if line[i]]
        predicted_labels = ' '.join(str(e) for e in pred)
        f.write(str(testImageId[x1]) + ',' + predicted_labels + '\n')
